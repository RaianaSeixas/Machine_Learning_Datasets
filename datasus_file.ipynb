# %% [markdown]
# <a href="https://colab.research.google.com/github/RaianaSeixas/Machine_Learning_Datasets/blob/main/datasus_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pysus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 13.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 64.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 69.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.6/500.6 kB 42.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 77.4 MB/s eta 0:00:00
# ...

# %%
import pysus
from pysus.utilities.readdbc import read_dbc
import pandas as pd

# %%
# !git clone https://github.com/ucfilho/Machine_Learning_DataSet
# %cd Machine_Learning_DataSet
# Out:
# Cloning into 'Machine_Learning_DataSet'...
# remote: Enumerating objects: 209, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 209 (delta 3), reused 0 (delta 0), pack-reused 195
# Receiving objects: 100% (209/209), 67.18 MiB | 24.12 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/Machine_Learning_DataSet

# %%
from pysus.utilities.readdbc import read_dbc

df = read_dbc('AMMG2212.dbc', encoding='iso-8859-1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134538 entries, 0 to 134537
# Data columns (total 51 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   AP_MVM      134538 non-null  object
#  1   AP_CONDIC   134538 non-null  object
#  2   AP_GESTAO   134538 non-null  object
#  3   AP_CODUNI   134538 non-null  object
#  4   AP_AUTORIZ  134538 non-null  object
#  5   AP_CMP      134538 non-null  object
#  6   AP_PRIPAL   134538 non-null  object
#  7   AP_VL_AP    134538 non-null  float64
#  8   AP_UFMUN    134538 non-null  object
#  9   AP_TPUPS    134538 non-null  object
#  10  AP_TIPPRE   134538 non-null  object
#  11  AP_MN_IND   134538 non-null  object
#  12  AP_CNPJCPF  134538 non-null  object
#  13  AP_CNPJMNT  134538 non-null  object
#  14  AP_CNSPCN   134538 non-null  object
#  15  AP_COIDADE  134538 non-null  object
#  16  AP_NUIDADE  134538 non-null  object
#  17  AP_SEXO     134538 non-null  object
# ...

# %%
df
# Out:
#         AP_MVM AP_CONDIC AP_GESTAO AP_CODUNI     AP_AUTORIZ  AP_CMP  \
# 0       202212        EP    310000   2194406  3122218421333  202212
# 1       202212        EP    310000   2179113  3122218320441  202212
# 2       202212        EP    310000   2767481  3122217251549  202212
# 3       202212        EP    310000   2768410  3122218211310  202212
# 4       202212        EP    310000   2768410  3122217991068  202212
# ...        ...       ...       ...       ...            ...     ...
# 134533  202212        EP    310000   2768399  3122218397903  202212
# 134534  202212        EP    310000   2768399  3122217406286  202212
# 134535  202212        EP    310000   2768410  3122218423170  202212
# 134536  202212        EP    310000   2768410  3122218410091  202212
# 134537  202212        EP    310000   2768445  3122217208132  202212
#
#          AP_PRIPAL  AP_VL_AP AP_UFMUN AP_TPUPS  ... AP_CIDCAS AP_CIDPRI  \
# 0       0604330022       0.0   312230       68  ...      0000      I200
# ...

# %%
df['AP_COIDADE'].describe()
# Out:
# count     134538
# unique         4
# top            4
# freq      134450
# Name: AP_COIDADE, dtype: object

# %%
df['AP_COIDADE'].hist()
# Out:
# <Axes: >

# %%
df['AP_NUIDADE'].describe()
# Out:
# count     134538
# unique       100
# top           52
# freq       11245
# Name: AP_NUIDADE, dtype: object

# %%
df[['AP_NUIDADE']]
# Out:
#        AP_NUIDADE
# 0              68
# 1              62
# 2              56
# 3              61
# 4              66
# ...           ...
# 134533         12
# 134534         13
# 134535         08
# 134536         09
# 134537         15
#
# [134538 rows x 1 columns]

# %%
df['AP_SEXO'].describe()
# Out:
# count     134538
# unique         2
# top            F
# freq       79072
# Name: AP_SEXO, dtype: object

# %%
# Distribuíção de frequências das variáveis
df.hist(figsize=(12,10),color='lightsteelblue');
